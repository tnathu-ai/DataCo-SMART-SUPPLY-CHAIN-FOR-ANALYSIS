# %% [markdown]
# <h1 style="color:#ffc0cb;font-size:70px;font-family:Georgia;text-align:center;"><strong>DataCo SMART SUPPLY CHAIN</strong></h1>

# %%
# Install a conda package in the current Jupyter kernel
import sys

# work with data in tabular representation
from datetime import time
import pandas as pd

# round the data in the correlation matrix
import numpy as np
import os
import glob

# run a python function file 
# %run ../src/cleaning.py

# ignore Depreca python function file 
# %run ../src/cleaning.py
​
# ignore DeprecationWarning Error Messages
import warnings
warnings.filterwarnings('ignore')
ationWarning Error Messages
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
from scipy.stats import kurtosis, skew

df = pd.read_csv('../data/external/dataco_supply_chain.csv', error_bad_lines=False, encoding= 'unicode_escape')

# convert to datetime datatype
df['shipping date (DateOrders)'] = pd.to_datetime(df['shipping date (DateOrders)'])

print("The shape of the ORGINAL data is (row, column):", str(df.shape))

# Remove two columns that have the most null values
df = df.drop(['Product Description', 'Order Zipcode'], axis = 1)

print()
profile_summary(df)
print("The shape of the AFTER data is (row, column):", str(df.shape))
# convert columns to the best possible dtypes, object->string
df = df.convert_dtypes()

# Cast all values inside the dataframe (except the columns' name) into lower case.
df = df.applymap(lambda s: s.lower() if type(s) == str else s)
    
# remove extra leading and trailing whitespace 
whitespace_remover(df)

df.info()
# Out:
# The shape of the ORGINAL data is (row, column): (180519, 53)
#
# Profiling datasets
#                         Attribute            Type  Num. Missing Values  Num. Unique Values            Sknewness   Kurtosis
# 0        Days for shipping (real)           int64                    0                   7             0.084771  -1.007919
# 1   Days for shipment (scheduled)           int64                    0                   4            -0.731992  -1.022954
# 2               Benefit per order         float64                    0               21998            -4.741795  71.375248
# 3              Sales per customer         float64                    0                2927             2.888422  23.919666
# 4              Late_delivery_risk           int64                    0                   2            -0.194073  -1.962336
# 5                     Category Id           int64                    0                  51             0.361622  -0.603278
# ...

# %% [markdown]
# <h1 style="color:#ffc0cb;font-size:70px;font-family:Georgia;text-align:center;"><strong>Rename columns to snake case</strong></h1>
# Clean columns to SQL Convention using [Skimpy](https://github.com/aeturrell/skimpy): by default what I get back is in snake case:

# %%
import pandas as pd
from rich import print
from skimpy import clean_columns

df = clean_columns(df)
print(list(df.columns))
# Out:
# [
#     'type',
#     'days_for_shipping_real',
#     'days_for_shipment_scheduled',
#     'benefit_per_order',
#     'sales_per_customer',
#     'delivery_status',
#     'late_delivery_risk',
#     'category_id',
#     'category_name',
#     'customer_city',
#     'customer_country',
#     'customer_email',
#     'customer_fname',
#     'customer_id',
#     'customer_lname',
#     'customer_password',
#     'customer_segment',
#     'customer_state',
#     'customer_street',
#     'customer_zipcode',
#     'department_id',
#     'department_name',
#     'latitude',
#     'longitude',
#     'market',
#     'order_city',
#     'order_country',
#     'order_customer_id',
#     'order_date_date_orders',
#     'order_id',
#     'order_item_cardprod_id',
#     'order_item_discount',
#     'order_item_discount_rate',
#     'order_item_id',
#     'order_item_product_price',
#     'order_item_profit_ratio',
#     'order_item_quantity',
#     'sales',
#     'order_item_total',
# ...

# %%
df.head()
# Out:
#        type  days_for_shipping_real  days_for_shipment_scheduled  \
# 0     debit                       3                            4
# 1  transfer                       5                            4
# 2      cash                       4                            4
# 3     debit                       3                            4
# 4   payment                       2                            4
#
#    benefit_per_order  sales_per_customer   delivery_status  \
# 0          91.250000          314.640015  advance shipping
# 1        -249.089996          311.359985     late delivery
# 2        -247.779999          309.720001  shipping on time
# 3          22.860001          304.809998  advance shipping
# 4         134.210007          298.250000  advance shipping
#
#    late_delivery_risk  category_id   category_name customer_city  ...  \
# 0                   0           73  sporting goods        caguas  ...
# 1                   1           73  sporting goods        caguas  ...
# ...

# %%
df.to_csv('../data/interim/dataco_supply_chain.csv', index=False)

# %% [markdown]
# <h1 style="color:#ffc0cb;font-size:70px;font-family:Georgia;text-align:center;"><strong>Description</strong></h1>

# %%
import numpy as np
from scipy.stats import kurtosis, skew

df = pd.read_csv('../data/external/description.csv', error_bad_lines=False, encoding= 'unicode_escape')

print("The shape of the ORGINAL data is (row, column):", str(df.shape))

print()
profile_summary(df)

# convert columns to the best possible dtypes, object->string
df = df.convert_dtypes()


# Cast all values inside the dataframe (except the columns' name) into lower case.
df = df.applymap(lambda s: s.lower() if type(s) == str else s)
    
# remove extra leading and trailing whitespace 
whitespace_remover(df)

# rename columns
df = clean_columns(df)
print(list(df.columns))

print(df.info())


df.to_csv('../data/interim/description.csv', index=False)

df.head()
# Out:
# The shape of the ORGINAL data is (row, column): (52, 2)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Profiling datasets
#      Attribute    Type  Num. Missing Values  Num. Unique Values Sknewness Kurtosis
# 0       FIELDS  object                    0                  52       N/A      N/A
# 1  DESCRIPTION  object                    0                  51       N/A      N/A
# ['fields', 'description']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fields       52 non-null     object
#  1   description  52 non-null     object
# dtypes: object(2)
# memory usage: 960.0+ bytes
# None
#                           fields  \
# 0                           type
# 1  days for shipping (real)
# 2  days for shipment (scheduled)
# ...

# %% [markdown]
# <h1 style="color:#ffc0cb;font-size:70px;font-family:Georgia;text-align:center;"><strong>LOGS DATASET</strong></h1>

# %%
import numpy as np
from scipy.stats import kurtosis, skew

df = pd.read_csv('../data/external/tokenized_access_logs.csv', error_bad_lines=False, encoding= 'unicode_escape')

print("The shape of the ORGINAL data is (row, column):", str(df.shape))

# convert to datetime datatype
df['Date'] = pd.to_datetime(df['Date'])

print()
profile_summary(df)

# convert columns to the best possible dtypes, object->string
df = df.convert_dtypes()

# Cast all values inside the dataframe (except the columns' name) into lower case.
df = df.applymap(lambda s: s.lower() if type(s) == str else s)
    
# remove extra leading and trailing whitespace 
whitespace_remover(df)

# rename columns
df = clean_columns(df)
print(list(df.columns))

print(df.info())


df.to_csv('../data/interim/logs.csv', index=False)

df.head()
# Out:
# The shape of the ORGINAL data is (row, column): (469977, 8)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Profiling datasets
#     Attribute            Type  Num. Missing Values  Num. Unique Values Sknewness  Kurtosis
# 0        Hour           int64                    0                  24 -0.234879 -0.957813
# 1     Product          object                    0                  76       N/A       N/A
# 2    Category          object                    0                  33       N/A       N/A
# 3        Date  datetime64[ns]                    0              160815       N/A       N/A
# 4       Month          object                    0                   5       N/A       N/A
# 5  Department          object                    0                   6       N/A       N/A
# 6          ip          object                    0                3340       N/A       N/A
# ...
